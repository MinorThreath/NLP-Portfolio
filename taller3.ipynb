# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguage Natural
#
# ## Taller #3: Web Scraping
# `Fecha de entrega: Marzo 10, 2021. (Antes del inicio de la próxima clase).`

# %% [markdown]
# # Punto 1:
#
# - `[15 pts]` Hacer Web Scraping de 10 animales en Wikipedia (en búcle)
# - `[10 pts]` Obtener el **encabezado** de cada animal
# - `[15 pts]` Obtener todos los **textos** que están en las etiquetas de negrilla del primer parrafo.

# %%
import bs4 as bs 
import urllib.request
import re

# %%
link = "https://es.wikipedia.org/wiki/Bubo"

# %%
req= urllib.request.Request(link,headers={'User-Agent':'Mozilla/5.0'})
wp=urllib.request.urlopen(req)
source=wp.read()
wp.close()
sp=bs.BeautifulSoup(source,'html.parser')
sp
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Bubo - Wikipedia, la enciclopedia libre</title>
# ...

# %%
#consulta por etiquetas
esp=[]
for link in sp.find_all('a'):
    esp.append(link.get('href'))
links=[]
lin = "https://es.wikipedia.org"
for i in range(43,53):
    links.append(lin+esp[i])

# %%
t=[]
for i in links:
    req= urllib.request.Request(i,headers={'User-Agent':'Mozilla/5.0'})
    wp=urllib.request.urlopen(req)
    source=wp.read()
    wp.close()
    sp=bs.BeautifulSoup(source,'html.parser')
    print(sp.find(id="firstHeading").text)
    p=sp.find("p").find_all("b")
    for tag in p:
        t.append(tag.text.strip())
print(t)
# Out:
# Bubo capensis
# Bubo cinerascens
# Bubo coromandus
# Bubo lacteus
# Bubo leucostictus
# Bubo magellanicus
# Bubo nipalensis
# Bubo philippensis
# Bubo poensis
# Bubo vosseleri
# ['búho vermiculado', 'búho ceniciento', 'Bubo cinerascens', 'búho sombrío', 'búho de Coromandel', 'búho surasiático', 'Bubo coromandus', 'búho lechoso', 'búho de Verreaux', 'Bubo lacteus', 'búho Akún', 'Bubo leucostictus', 'búho de Nepal', 'búho de bosque', 'Bubo nipalensis', 'búho filipino', 'Bubo philippensis', 'búho de Guinea', 'búho Nduk', 'búho de Fraser', 'Bubo poensis', 'búho de Usambara', 'Bubo poensis vosseleri']

# %% [markdown]
# # Punto 2:
# - `[10 pts]` Usando regex, reemplazar todos los caracteres especiales del punto  inmediatamente anterior por un asterisco (¡Ojo, los espacios se quedan!)

# %%
re.sub(r"[^\W^a-zA-Z]","*",str(t))
# Out:
# "['b*ho vermiculado', 'b*ho ceniciento', 'Bubo cinerascens', 'b*ho sombr*o', 'b*ho de Coromandel', 'b*ho surasi*tico', 'Bubo coromandus', 'b*ho lechoso', 'b*ho de Verreaux', 'Bubo lacteus', 'b*ho Ak*n', 'Bubo leucostictus', 'b*ho de Nepal', 'b*ho de bosque', 'Bubo nipalensis', 'b*ho filipino', 'Bubo philippensis', 'b*ho de Guinea', 'b*ho Nduk', 'b*ho de Fraser', 'Bubo poensis', 'b*ho de Usambara', 'Bubo poensis vosseleri']"
